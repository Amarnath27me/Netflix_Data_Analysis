# %% [markdown]
# # Netflix Data Analysis
#
# ## Introduction
#
# The streaming industry has transformed how audiences consume entertainment, with Netflix at the forefront of this shift. This project analyzes the Netflix dataset, containing information on movies and TV shows available on the platform. Objectives are:
#
# - Understand the distribution of content types (movies vs. TV shows)
# - Identify popular genres and countries of production
# - Explore trends in content release over time
# - Examine relationships between key features like duration and ratings
#
# Through data cleaning, exploratory data analysis (EDA), and visualizations, I aim to uncover actionable insights that could inform content strategies or user engagement efforts.

# %% [markdown]
# ![Color-Netflix-Logo-2109918665.jpg](attachment:cfee72c2-2e83-437f-97d1-b59d43dd2e2e.jpg)

# %% [markdown]
# This Netflix Dataset has information about the TV Shows and Movies available on Netflix till 2021.
#
# This dataset is collected from Flixable which is a third-party Netflix search engine, and available on Kaggle website for free.
#
#
# ## Objectives
#
# - Clean and preprocess the dataset for analysis
# - Handle missing values and inconsistencies
# - Visualize key distributions and trends using plots
# - Answer key business questions about Netflix’s content library
#
# Let's start by loading the data and exploring its structure.

# %% [markdown]
# ----------

# %% [markdown]
# ## Importing Data Set and Important libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
sns.set_palette('pastel')
plt.rcParams['figure.figsize'] = (10, 6)

data = pd.read_csv("D:\\netflix_dataset.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Analyzing the dataset

# %% [markdown]
# ## 1. head()

# %%
data.head()               ## to get top 5 records of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %% [markdown]
# ## 2. tail()

# %%
data.tail()               ##to get the bottom 5 records of the dataset
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 8802  20-Nov-19          2007      R    158 min
# 8803   1-Jul-19          2018  TV-Y7  2 Seasons
# 8804   1-Nov-19          2009      R     88 min
# ...

# %% [markdown]
# ## 3.shape

# %%
data.shape                   ## to see the dimensionality of the dataset(no.of rows and columns)
# Out:
# (8807, 12)

# %% [markdown]
# ## 4.size

# %%
data.size                   ## to see the total no.of elements present in the dataset
# Out:
# 105684

# %% [markdown]
# ## 5.columns

# %%
data.columns                ## to retrieve column names present in the dataset
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ## 6.dtypes

# %%
data.dtypes                   ## to show the data-type of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ## 7.info

# %%
data.info()               ## to show concise summary of our dataset includingindexes,columns, data-types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# --------------

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Task 1: To find if any duplicate records are present in the dataset? If yes, then remove the duplicate records.

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data[data.duplicated()]                     ## to check if duplicated are present
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ## Task 2: To check if any Null values are present in any column? Show them with Heat-map.

# %%
data.isnull()                            ## to check if any null values are present
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False     False  False     True       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False     False  False     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()              ## getting a sum of null values present
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## seaborn library (heat-map)

# %%
import seaborn as sns                 ## plotting a heat-map for null values
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## Task 3: To convert the column names in proper title form.

# %%
data.columns             ## to retrieve all columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.columns = data.columns.str.title()      ## converting all columns with proper title format

# %%
data.head()
# Out:
#   Show_Id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   Date_Added  Release_Year Rating   Duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %% [markdown]
# ## Task 4:  To replace null values in Director and Cast columns with Unknown.

# %%
data['Director'].fillna('Unknown', inplace=True)
data['Cast'].fillna('Unknown', inplace=True)

print("Missing values handled: 'director' and 'cast' columns filled with 'Unknown'.")
# Out:
# Missing values handled: 'director' and 'cast' columns filled with 'Unknown'.
# C:\Users\Amarnath\AppData\Local\Temp\ipykernel_14532\602500219.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Director'].fillna('Unknown', inplace=True)
# C:\Users\Amarnath\AppData\Local\Temp\ipykernel_14532\602500219.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# -------------------------------

# %% [markdown]
# ## Q1. For 'Houe of Cards', what is the Show Id and Who is the Director of the show?

# %% [markdown]
# ## isin()

# %%
data.head()
# Out:
#   Show_Id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 Cast        Country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                            Unknown            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   Date_Added  Release_Year Rating   Duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
data[data['Title'].isin(['House of Cards'])]     ## to show records of a particular item in a column
# Out:
#      Show_Id     Type           Title Director  \
# 1059   s1060  TV Show  House of Cards  Unknown
#
#                                                    Cast        Country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Date_Added  Release_Year Rating   Duration                Listed_In  \
# 1059  14-Apr-21          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## str.contain()

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id     Type           Title Director  \
# 1059   s1060  TV Show  House of Cards  Unknown
#
#                                                    Cast        Country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Date_Added  Release_Year Rating   Duration                Listed_In  \
# 1059  14-Apr-21          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# -------------

# %% [markdown]
# ## Q2. In which year were the highest number of TV Shows & Movies were added to Netflix? Plot a Bar Graph.

# %% [markdown]
# ## to_datetime

# %%
data.dtypes            ## checking datatypes of the columns
# Out:
# Show_Id         object
# Type            object
# Title           object
# Director        object
# Cast            object
# Country         object
# Date_Added      object
# Release_Year     int64
# Rating          object
# Duration        object
# Listed_In       object
# Description     object
# dtype: object

# %%
data['Date_Added'] = pd.to_datetime(data['Date_Added'])  ## converting the Date_Added Column to datetime datatype
# Out:
# C:\Users\Amarnath\AppData\Local\Temp\ipykernel_14532\645537137.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date_Added'] = pd.to_datetime(data['Date_Added'])  ## converting the Date_Added Column to datetime datatype

# %%
data.head()
# Out:
#   Show_Id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 Cast        Country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                            Unknown            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   Date_Added  Release_Year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
data.dtypes                ## checking the data types ensuing the changes has been made
# Out:
# Show_Id                 object
# Type                    object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Date_Added      datetime64[ns]
# Release_Year             int64
# Rating                  object
# Duration                object
# Listed_In               object
# Description             object
# dtype: object

# %%
data['Date_Added'].dt.year.value_counts()     ## counts the occurrences of all Individual years in Date_Added Column
# Out:
# Date_Added
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# ## Bar Graph

# %%
data['Date_Added'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_Added'>

# %% [markdown]
# -----------

# %% [markdown]
# ## Q3. How many Movies & TV Shows are in the dataset? Plot a Counter Plot

# %% [markdown]
# ## groupby

# %%
data.groupby('Type').Type.count()         ## groups unique items of a column and shows their count
# Out:
# Type
# Movie      6131
# TV Show    2676
# Name: Type, dtype: int64

# %% [markdown]
# ## countplot()

# %%
# Countplot for content type
sns.countplot(x='Type', data=df)
plt.title('Distribution of Content Type on Netflix')
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ------------------------

# %% [markdown]
# ## Q4. Show all the Movies added in the year 2020.

# %% [markdown]
# ## Creating a new column

# %%
data['Year'] = data['Date_Added'].dt.year   ## creating a new column year extracting only year from Date_Added column

# %%
data.head(2)
# Out:
#   Show_Id     Type                 Title         Director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          Unknown
#
#                                                 Cast        Country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   Date_Added  Release_Year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          Listed_In  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description    Year
# 0  As her father nears the end of his life, filmm...  2021.0
# 1  After crossing paths at a party, a Cape Town t...  2021.0

# %% [markdown]
# ## Filtering (And)

# %%
data[(data['Type'] == 'Movie') & (data['Year'] == 2020)]  ## Filtering Movie Type and Year 2020
# Out:
#      Show_Id   Type                                Title  \
# 1470   s1471  Movie                     Alaska Is a Drag
# 1471   s1472  Movie                Best of Stand-Up 2020
# 1472   s1473  Movie                         Bobby Jasoos
# 1474   s1475  Movie                        Tarung Sarung
# 1475   s1476  Movie               Too Handsome to Handle
# ...      ...    ...                                  ...
# 8742   s8743  Movie                       Wild Wild West
# 8743   s8744  Movie                             Wildlife
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory
# 8764   s8765  Movie                           Wyatt Earp
# 8805   s8806  Movie                                 Zoom
#
#                        Director  \
# 1470               Shaz Bennett
# 1471                    Unknown
# 1472               Samar Shaikh
# 1474            Archie Hekagery
# 1475  Sabrina Rochelle Kalangie
# ...                         ...
# 8742           Barry Sonnenfeld
# ...

# %% [markdown]
# ------------------------

# %% [markdown]
# ## Q5. Show only the Titles of all TV Shows that were released in the United States only.

# %%
data [ (data['Type'] =='TV Show') & (data ['Country'] == 'United States')] ['Title']
# Out:
# 15                           Dear White People
# 40      He-Man and the Masters of the Universe
# 55                                   Nailed It
# 67                           Saved by the Bell
# 82                                     Lucifer
#                          ...
# 8710                                     Weeds
# 8726                      When Calls the Heart
# 8747                                 Winsanity
# 8755                         Women Behind Bars
# 8780                              Yo-Kai Watch
# Name: Title, Length: 760, dtype: object

# %% [markdown]
# ## Content added over the years

# %%
content_year = df['Release_Year'].value_counts().sort_index()
plt.plot(content_year.index, content_year.values, marker='o', linestyle='-')
plt.title('Content Added Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ---------------------

# %% [markdown]
# ## Q6. Show Top 10 Directors, who gave the highest number of TV Shows and Movies to Netflix.

# %%
data['Director'].value_counts().head(10)
# Out:
# Director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# -----------------------

# %% [markdown]
# ## Q7. Show all Records, where Type is Movie and Listed_In Comedies or Country is United Kingdom.

# %% [markdown]
# ## Filtering (OR)

# %%
data[ (data['Type'] == 'Movie') & (data['Listed_In'] == 'Comedies')]   ## filtering data where type is movie & listed_in comedies
# Out:
#      Show_Id   Type                                   Title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   Director                                               Cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
data [ (data['Type'] =='Movies') & (data['Listed_In'] == 'Comedies') | (data['Country'] == 'United Kingdom')]
# Out:
#      Show_Id     Type                                   Title  \
# 8         s9  TV Show           The Great British Baking Show
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# 98       s99  TV Show               Octonauts: Above & Beyond
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              Director                                               Cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %% [markdown]
# -------------

# %% [markdown]
# ## Q8. What are the different Ratings defined by Netflix?

# %% [markdown]
# ## nunique()

# %%
data['Rating'].nunique()
# Out:
# 17

# %%
data['Rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ---------------------

# %% [markdown]
# ## Q9.1: How many movies got the 'R' rating, in India?

# %%
data[(data['Type'] == 'Movie') & (data['Rating'] == 'R')].shape  #filtering what movies have rating 'R'
# Out:
# (797, 13)

# %%
data[(data['Type'] == 'Movie') & (data['Rating'] == 'R') & (data['Country'] =='India')].shape
# Out:
# (1, 13)

# %% [markdown]
# ## Q9.2: How many TV Shows got the 'R' rating, after year 2018?

# %%
data[(data['Type'] == 'TV Show') & (data['Rating'] == 'R')]  #filtering tv shows with rating R
# Out:
#      Show_Id     Type                                Title           Director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    Cast Country Date_Added  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN 2019-04-25
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway 2016-12-10
#
#       Release_Year Rating  Duration  \
# 3893          2015      R  1 Season
# 7593          2016      R  1 Season
#
#                                             Listed_In  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             Description    Year
# 3893  Trapped at a stagecoach stop as a storm rages ...  2019.0
# 7593  A series of incidents in Afghanistan set compl...  2016.0

# %%
data[(data['Type'] == 'TV Show') & (data ['Rating'] == 'R') & (data['Year'] > 2018)]  ## checking R rated TV Shows after year 2018
# Out:
#      Show_Id     Type                                Title           Director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Date_Added  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN 2019-04-25
#
#       Release_Year Rating  Duration Listed_In  \
# 3893          2015      R  1 Season  TV Shows
#
#                                             Description    Year
# 3893  Trapped at a stagecoach stop as a storm rages ...  2019.0

# %% [markdown]
# -----------------

# %% [markdown]
# ## Q10. Which individual country has the Highest No. of TV Shows?

# %%
data.head(2)
# Out:
#   Show_Id     Type                 Title         Director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          Unknown
#
#                                                 Cast        Country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   Date_Added  Release_Year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          Listed_In  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description    Year
# 0  As her father nears the end of his life, filmm...  2021.0
# 1  After crossing paths at a party, a Cape Town t...  2021.0

# %%
data[data['Type'] == 'TV Show']
# Out:
#      Show_Id     Type                  Title         Director  \
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V          Unknown
# 8796   s8797  TV Show             Yunus Emre          Unknown
# 8797   s8798  TV Show              Zak Storm          Unknown
# 8800   s8801  TV Show     Zindagi Gulzar Hai          Unknown
# 8803   s8804  TV Show            Zombie Dumb          Unknown
#
#                                                    Cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
data[data['Type'] == 'TV Show'].Country.value_counts()
# Out:
# Country
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 196, dtype: int64

# %%
data[data['Type'] == 'TV Show'].Country.value_counts().head(1)
# Out:
# Country
# United States    760
# Name: count, dtype: int64

# %% [markdown]
#  -----------------

# %% [markdown]
# # Conclusion
#
# In this project, I've analyzed Netflix’s catalog to uncover insights about its content library. Key takeaways:
#
# - **Content Type:** Movies outnumber TV shows, but shows have grown steadily in recent years.
# - **Genres:** Drama is the most prevalent genre, followed by Comedy and Action.
# - **Countries:** The United States dominates content production, but international content is expanding.
# - **Release Years:** Most titles were released from 2015-2020, reflecting the growth of streaming.
#
# **Limitations:**
# - No user ratings or viewership data.
# - Missing values in 'director' and 'cast' may limit some analyses.
#
# **Future Work:**
# - Incorporate user data for deeper insights.
# - Text analysis on titles and descriptions.
# - Clustering based on genre, country, and duration.
#
# This analysis provides a foundation for further exploration and business decision-making.
